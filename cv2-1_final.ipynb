# %% [markdown]
# <a href="https://colab.research.google.com/github/Rango-Zhang-Hang/NTU-AI6121-CV/blob/main/cv2-1_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/jhoffman/cycada_release.git
# Out:
# Cloning into 'cycada_release'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 68 (delta 0), reused 1 (delta 0), pack-reused 65
# Unpacking objects: 100% (68/68), done.

# %%
# dataset: ./gdrive/MyDrive/gta2city

# %%
cd cycada_release/
# Out:
# /content/cycada_release

# %%
ls
# Out:
# cycada/  cyclegan/  LICENSE  README.md  requirements.txt  scripts/  setup.sh

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 36.7 MB/s
# ...

# %% [markdown]
# Use the evaluation model

# %%
mv scripts/test_21.py test_21.py
# Out:
# mv: cannot stat 'scripts/test_21.py': No such file or directory

# %%
# !ls
# Out:
# cycada	cyclegan  LICENSE  README.md  requirements.txt	scripts  setup.sh

# %%
cd ..
# Out:
# /content

# %%
cp gdrive/MyDrive/cityscapes.zip cycada_release/cityscapes.zip

# %%
# !ls
# Out:
# cycada_release	gdrive	sample_data

# %%
cd cycada_release
# Out:
# /content/cycada_release

# %%
# !unzip cityscapes.zip
# Out:
# Archive:  cityscapes.zip
#    creating: cityscapes/
#    creating: cityscapes/gtFine/
#   inflating: cityscapes/gtFine/license.txt
#   inflating: cityscapes/gtFine/README
#    creating: cityscapes/gtFine/val/
#    creating: cityscapes/gtFine/val/tubingen/
#   inflating: cityscapes/gtFine/val/tubingen/tubingen_000000_000019_gtFine_color.png
#   inflating: cityscapes/gtFine/val/tubingen/tubingen_000000_000019_gtFine_instanceIds.png
#   inflating: cityscapes/gtFine/val/tubingen/tubingen_000000_000019_gtFine_labelIds.png
#   inflating: cityscapes/gtFine/val/tubingen/tubingen_000000_000019_gtFine_polygons.json
#   inflating: cityscapes/gtFine/val/tubingen/tubingen_000001_000019_gtFine_color.png
#   inflating: cityscapes/gtFine/val/tubingen/tubingen_000001_000019_gtFine_instanceIds.png
#   inflating: cityscapes/gtFine/val/tubingen/tubingen_000001_000019_gtFine_labelIds.png
#   inflating: cityscapes/gtFine/val/tubingen/tubingen_000001_000019_gtFine_polygons.json
# ...

# %% [markdown]
# back to cycada_release

# %% [markdown]
# Run the evaluation with model

# %%
mkdir model

# %%
cd ..
# Out:
# /content

# %%
cp gdrive/MyDrive/cv_21_model.pth cycada_release/model/cv_21_model.pth

# %%
# !git clone https://github.com/Rango-Zhang-Hang/NTU-AI6121-CV.git
# Out:
# Cloning into 'NTU-AI6121-CV'...
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 75 (delta 34), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (75/75), done.

# %%
cp NTU-AI6121-CV/test_21.py cycada_release/test_21.py

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
cd cycada_release
# Out:
# /content/cycada_release

# %%
# !ls
# Out:
# cityscapes	cycada	  LICENSE  README.md	     scripts   test_21.py
# cityscapes.zip	cyclegan  model    requirements.txt  setup.sh

# %%
# !pip install torchvision==0.2.2.post3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 64 kB 115 kB/s
# ...
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.10 requires torchvision>=0.8.2, but you have torchvision 0.2.2.post3 which is incompatible.
# ...

# %%
# !ls
# Out:
# cityscapes	cycada	  LICENSE  README.md	     scripts   test_21.py
# cityscapes.zip	cyclegan  model    requirements.txt  setup.sh

# %%
mkdir result

# %%
# !python test_21.py 'model/cv_21_model.pth' --dataset cityscapes --datadir 'cityscapes' --model drn26
# Out:
# Using state dict from model/cv_21_model.pth
# Loading full model
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 0it [00:00, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3722: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# ...
# 1it [00:12, 12.27s/it, mIoU=16.42  fwIoU: 49.63 pixel acc: 62.82 per cls acc: 25.33]====================
# ...

# %% [markdown]
# #save to gdrive

# %%
# !zip -r result.zip result
# Out:
#   adding: result/ (stored 0%)
